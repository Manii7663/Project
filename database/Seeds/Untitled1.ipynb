# %%
from faker import Faker
import random
from datetime import datetime, timedelta
import os
import pymongo
from bson import ObjectId
import csv
import pandas as pd

# %%
fake=Faker()

# %%
mongo_connection_string =  "mongodb+srv://manii:1234@cluster0.bditt1m.mongodb.net/project?retryWrites=true&w=majority&appName=Cluster0"

os.environ['Project'] = 'project'

try:
    
    # Connect to MongoDB Atlas
    client = pymongo.MongoClient(mongo_connection_string)
    db = client[os.environ['Project']]
    
    # Print connection success message
    print("Connected to MongoDB Atlas successfully!")

    # Now, you can perform further operations with mongo_client and mongo_db
except pymongo.errors.ConnectionFailure as e:
    # Print connection failure message
    print(f"Failed to connect to MongoDB Atlas: {e}")

collection = db["users"]
# Out:
# Connected to MongoDB Atlas successfully!

# %%
# List of _id values
_id_values = [
    "66053fefd7c487757f97efbc",
    "660feb0a6f3688dd93b442ff",
    "660feb0a6f3688dd93b443a3",
    "660feb0a6f3688dd93b44314",
    "660feb0a6f3688dd93b44371",
    "660feb0a6f3688dd93b44321",
    "660feb0a6f3688dd93b4439a",
    "660feb0a6f3688dd93b44384",
    "660feb0a6f3688dd93b4435e",
    "660feb0a6f3688dd93b443a5",
    "660feb0a6f3688dd93b4432c",
    "660feb0a6f3688dd93b44388",
    "660feb0a6f3688dd93b4432e",
    "660feb0a6f3688dd93b443bb",
    "660feb0a6f3688dd93b443b3",
    "660feb0a6f3688dd93b44393",
    "660feb0a6f3688dd93b44323",
    "660feb0a6f3688dd93b44352",
    "660feb0a6f3688dd93b4434e",
    "660feb0a6f3688dd93b44306",
    "660feb0a6f3688dd93b44346",
    "660feb0a6f3688dd93b44331",
    "660feb0a6f3688dd93b4439b",
    "660feb0a6f3688dd93b4433b",
    "660feb0a6f3688dd93b4433a",
    "660feb0a6f3688dd93b44340",
    "660feb0a6f3688dd93b44345",
    "660feb0a6f3688dd93b4430b",
    "660feb0a6f3688dd93b443af",
    "660feb0a6f3688dd93b4430c",
    "660feb0a6f3688dd93b443ab",
    "660feb0a6f3688dd93b44390",
    "660feb0a6f3688dd93b44329",
    "660feb0a6f3688dd93b443a2",
    "660feb0a6f3688dd93b44310",
    "660feb0a6f3688dd93b4438d",
    "660feb0a6f3688dd93b4438b",
    "660feb0a6f3688dd93b44311",
    "660feb0a6f3688dd93b4431b",
    "660feb0a6f3688dd93b44316",
    "660feb0a6f3688dd93b443a0",
    "660feb0a6f3688dd93b443c2",
    "660feb0a6f3688dd93b443b6",
    "660feb0a6f3688dd93b44385",
    "660feb0a6f3688dd93b44364",
    "660feb0a6f3688dd93b44377",
    "660feb0a6f3688dd93b442fe",
    "660feb0a6f3688dd93b44348",
    "660feb0a6f3688dd93b4437e",
    "660feb0a6f3688dd93b4432f",
    "660feb0a6f3688dd93b4433e",
    "660feb0a6f3688dd93b44379",
    "660feb0a6f3688dd93b44382",
    "660feb0a6f3688dd93b44308",
    "660feb0a6f3688dd93b44366",
    "660feb0a6f3688dd93b44381",
    "660feb0a6f3688dd93b44373",
    "660feb0a6f3688dd93b4437c",
    "660feb0a6f3688dd93b4431f",
    "660feb0a6f3688dd93b44339",
    "660feb0a6f3688dd93b4435a",
    "660feb0a6f3688dd93b4438e",
    "660feb0a6f3688dd93b4435d",
    "660feb0a6f3688dd93b443b7",
    "660feb0a6f3688dd93b443c1"
]

# %%
# Loop through each _id value
for index, _id in enumerate(_id_values, start=1):
    user_data = {
        "_id": _id,
        "id": "EMP" + str(index).zfill(3),  # Assuming _id is appended to EMP
        "name": fake.name(),
        "email": fake.email(),
        "role": 'Employee',
        "Designation": random.choice(["Manager", "Software Engineer", "Data Analyst","Solution Enabler","Solution Consultant","Senior Software Engineer","Data Engineer", "Developer"]),
        "createdAt": fake.date_time_between(start_date="-7y", end_date="now").strftime("%Y-%m-%d %H:%M:%S"),
        "password": fake.password(length=8),  # Ensures password is at least 8 characters long
    }
    
    # Insert the generated fake data into the collection
    collection.insert_one(user_data)
    print(user_data)

print("Fake data inserted successfully.")

# Close the MongoDB connection
client.close()
# Out:
# {'_id': '66053fefd7c487757f97efbc', 'id': 'EMP001', 'name': 'Tyler Campbell', 'email': 'natasha72@example.net', 'role': 'Employee', 'Designation': 'Developer', 'createdAt': '2017-07-11 14:48:27', 'password': '(O(#9Pbi'}
# {'_id': '660feb0a6f3688dd93b442ff', 'id': 'EMP002', 'name': 'Aaron Robinson', 'email': 'williamsaudrey@example.com', 'role': 'Employee', 'Designation': 'Manager', 'createdAt': '2021-08-26 06:48:43', 'password': 'w_1YISqk'}
# {'_id': '660feb0a6f3688dd93b443a3', 'id': 'EMP003', 'name': 'Daniel Warner', 'email': 'gailhayes@example.org', 'role': 'Employee', 'Designation': 'Software Engineer', 'createdAt': '2019-07-16 20:09:09', 'password': '%8VXVPgp'}
# {'_id': '660feb0a6f3688dd93b44314', 'id': 'EMP004', 'name': 'Willie Lamb', 'email': 'brentlee@example.org', 'role': 'Employee', 'Designation': 'Senior Software Engineer', 'createdAt': '2024-02-27 18:22:26', 'password': '^7FY4Tlf'}
# ...

# %%
for i in range(1, 200):
    user_data = {
        "id": "EMP" + str(i),
        "name": fake.name(),
        "email": fake.email(),
        "role": 'Employee',
        "Designation": random.choice(["Manager", "Software Engineer", "Data Analyst","Solution Enabler","Solution Consultant","Senior Software Engineer","Data Engineer", "Developer"]),
        "createdAt": fake.date_time_between(start_date="-7y", end_date="now").strftime("%Y-%m-%d %H:%M:%S"),
        "password": fake.password(length=8),  # Ensures password is at least 8 characters long
    }
    fake_data_list.append(user_data)
